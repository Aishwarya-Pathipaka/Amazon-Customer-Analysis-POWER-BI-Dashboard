# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\Projects\Amazon Customer Analysis\mta-customer-feedback-data-beginning-2014-1.csv")

# %%
df.columns
# Out:
# Index(['Agency', 'Commendation or Complaint', 'Subject Matter',
#        'Subject Detail', 'Issue Detail', 'Year', 'Quarter',
#        'Branch/Line/Route'],
#       dtype='object')

# %%
df.head()
# Out:
#                   Agency Commendation or Complaint Subject Matter  \
# 0  Long Island Rail Road              Commendation      Employees
# 1  Long Island Rail Road              Commendation      Employees
# 2  Long Island Rail Road              Commendation      Employees
# 3  Long Island Rail Road              Commendation      Employees
# 4  Long Island Rail Road              Commendation      Employees
#
#                   Subject Detail             Issue Detail  Year  Quarter  \
# 0               CSR - Ambassador    Very Helpful/Friendly  2015        2
# 1               CSR - Ambassador    Very Helpful/Friendly  2015        2
# 2  CSR - Customer Service Office                      NaN  2015        1
# 3  CSR - Customer Service Office                    Other  2015        2
# 4  CSR - Customer Service Office  Very Helpful / Friendly  2015        2
#
#   Branch/Line/Route
# 0          No Value
# 1    Port Jefferson
# 2          No Value
# 3      Far Rockaway
# 4          No Value

# %%
df.describe()
# Out:
#                 Year        Quarter
# count  183887.000000  183887.000000
# mean     2015.737991       2.756938
# std         0.815389       1.110994
# min      2014.000000       1.000000
# 25%      2015.000000       2.000000
# 50%      2016.000000       3.000000
# 75%      2016.000000       4.000000
# max      2017.000000       4.000000

# %%
df.shape
# Out:
# (183887, 8)

# %%
df.isna().sum()
# Out:
# Agency                           0
# Commendation or Complaint        0
# Subject Matter                   0
# Subject Detail                   0
# Issue Detail                 10134
# Year                             0
# Quarter                          0
# Branch/Line/Route                0
# dtype: int64

# %%
df['Issue Detail']
# Out:
# 0                            Very Helpful/Friendly
# 1                            Very Helpful/Friendly
# 2                                              NaN
# 3                                            Other
# 4                          Very Helpful / Friendly
#                             ...
# 183882    No Announcement / Messages - Visual/Text
# 183883    No Announcement / Messages - Visual/Text
# 183884    No Announcement / Messages - Visual/Text
# 183885                  Timeliness - Visual / Text
# 183886                  Timeliness - Visual / Text
# Name: Issue Detail, Length: 183887, dtype: object

# %%
df.drop('Issue Detail',axis=1,inplace=True)

# %%
df
# Out:
#                        Agency Commendation or Complaint  \
# 0       Long Island Rail Road              Commendation
# 1       Long Island Rail Road              Commendation
# 3       Long Island Rail Road              Commendation
# 4       Long Island Rail Road              Commendation
# 5       Long Island Rail Road              Commendation
# ...                       ...                       ...
# 183882                Subways                 Complaint
# 183883                Subways                 Complaint
# 183884                Subways                 Complaint
# 183885                Subways                 Complaint
# 183886                Subways                 Complaint
#
#                           Subject Matter                 Subject Detail  Year  \
# 0                              Employees               CSR - Ambassador  2015
# 1                              Employees               CSR - Ambassador  2015
# ...

# %%
df.head()
# Out:
#                   Agency Commendation or Complaint Subject Matter  \
# 0  Long Island Rail Road              Commendation      Employees
# 1  Long Island Rail Road              Commendation      Employees
# 3  Long Island Rail Road              Commendation      Employees
# 4  Long Island Rail Road              Commendation      Employees
# 5  Long Island Rail Road              Commendation      Employees
#
#                   Subject Detail  Year  Quarter Branch/Line/Route
# 0               CSR - Ambassador  2015        2          No Value
# 1               CSR - Ambassador  2015        2    Port Jefferson
# 3  CSR - Customer Service Office  2015        2      Far Rockaway
# 4  CSR - Customer Service Office  2015        2          No Value
# 5  CSR - Customer Service Office  2014        3          No Value

# %%
df.to_excel('C:\Projects\Amazon Customer Analysis\Final Datasett.xlsx',index=False)
